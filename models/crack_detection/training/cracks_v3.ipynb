# %% [markdown]
# # Cracked Phone Screen Detector v3 - ConvNeXt-Tiny
#
# Fixes applied from the v2 debugging session:
#
# 1. **RAM leak in the data pipeline** - shuffle buffer and `.cache()` were holding
#    unbatched float32 384px images (1.77MB/image). Now cached as uint8 (442KB/image)
#    with a small shuffle buffer and bounded prefetch.
# 2. **Val/test contamination** - v2's val set hit PR-AUC 1.0 by epoch 5 on a frozen
#    backbone while test recall on real cracks was 0.286, and Grad-CAM showed the
#    model wasn't localizing to cracks at all. This notebook starts from a single
#    merged, hash-deduplicated pool and re-splits 70/20/10, stratified, preserving
#    the real ~20% cracked class ratio in every split (not forced 50/50).
# 3. **Model likely oversized for ~1150 train images** - ConvNeXt-**Tiny** instead
#    of Base/Large, and a smaller fine-tune fraction (0.15 instead of 0.25).
#
# **You are expected to have already manually reviewed images for mislabeling
# before running this notebook** - dedup here catches exact/near duplicates, not
# wrong labels. No amount of pipeline fixing substitutes for that review.

# %% [markdown]
# ## 1. Setup

# %%
import os, json, random, shutil, hashlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix, classification_report, precision_recall_curve,
    average_precision_score, roc_auc_score,
)

SEED = 1337
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    tf.keras.mixed_precision.set_global_policy("mixed_float16")

print("policy :", tf.keras.mixed_precision.global_policy().name)
print("gpu    :", tf.config.list_physical_devices("GPU"))
assert tf.config.list_physical_devices("GPU"), "No GPU visible - check Runtime > Change runtime type"
# Out:
# policy : mixed_float16
# gpu    : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Point this at your reviewed pool
#
# After merging everything into `train/` and doing your manual review, put the
# two class folders directly under `POOL_DIR` (not nested under train/val/test -
# this notebook builds the split for you).
#
# ```
# crackeddataset_pool/
#   cracked/
#   not_cracked/
# ```

# %%
from google.colab import drive
drive.mount("/content/drive")

DRIVE_POOL = "/content/drive/MyDrive/crackdata"   # <-- your reviewed, merged folder
LOCAL_POOL = "/content/crackdata"

if not os.path.exists(LOCAL_POOL):
    print("Copying reviewed pool to local disk...")
    shutil.copytree(DRIVE_POOL, LOCAL_POOL)

CLASS_NAMES = sorted(d for d in os.listdir(LOCAL_POOL)
                     if os.path.isdir(os.path.join(LOCAL_POOL, d)))
print("classes:", CLASS_NAMES)
for c in CLASS_NAMES:
    print(f"  {c}: {len(os.listdir(os.path.join(LOCAL_POOL, c)))} images")
# Out:
# Mounted at /content/drive
# Copying reviewed pool to local disk...
# classes: ['cracked', 'not_cracked']
#   cracked: 385 images
#   not_cracked: 650 images

# %% [markdown]
# ## 3. Config

# %%
IMG_SIZE   = (384, 384)
BATCH_SIZE = 16             # bump to 32 in stage 2 and watch the GPU RAM gauge

EPOCHS_HEAD     = 12
EPOCHS_FINETUNE = 15
LR_HEAD         = 1e-3
LR_FINETUNE     = 1e-5

FINE_TUNE_FRACTION = 0.15   # smaller than v2's 0.25 - less capacity for ~1150 train images
TARGET_PRECISION   = 0.90

VAL_FRACTION  = 0.20
TEST_FRACTION = 0.10

SPLIT_DIR = "/content/crackeddataset_split"
CACHE_DIR = "/content/tfcache"
CKPT      = "/content/best_crack_model.keras"
os.makedirs(CACHE_DIR, exist_ok=True)

AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# ## 4. Deduplicate the pool
#
# Exact-duplicate and near-duplicate photos of the same physical crack were the
# prime suspect for why v2's val set was trivially easy. Exact dupes are caught
# by content hash; near-dupes (same crack, slightly different crop/angle) need a
# perceptual hash since a single-pixel shift changes the exact hash completely.

# %%
try:
    import imagehash
except ImportError:
    import subprocess, sys
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "ImageHash"], check=True)
    import imagehash
from PIL import Image

def scan_pool():
    records = []  # (path, class, md5, phash)
    for c in CLASS_NAMES:
        folder = os.path.join(LOCAL_POOL, c)
        for fname in os.listdir(folder):
            p = os.path.join(folder, fname)
            try:
                raw = open(p, "rb").read()
                img = Image.open(p).convert("RGB")
            except Exception as e:
                print("UNREADABLE, skipping:", p, e)
                continue
            records.append({
                "path": p, "class": c,
                "md5": hashlib.md5(raw).hexdigest(),
                "phash": imagehash.phash(img),
            })
    return records

records = scan_pool()
print(f"scanned {len(records)} readable images")

# exact duplicates
seen_md5, exact_dupes = {}, []
for r in records:
    if r["md5"] in seen_md5:
        exact_dupes.append(r["path"])
    else:
        seen_md5[r["md5"]] = r["path"]
print(f"{len(exact_dupes)} exact duplicates")

# near-duplicates: small Hamming distance between perceptual hashes.
# Keep the first occurrence of each near-dupe cluster, drop the rest.
keep = [r for r in records if r["md5"] not in set(exact_dupes)]
# actually rebuild keep properly: first-seen-wins over md5
keep = []
seen = set()
for r in records:
    if r["md5"] in seen:
        continue
    seen.add(r["md5"])
    keep.append(r)

PHASH_THRESHOLD = 6   # Hamming distance; lower = stricter. 6 is a common near-dupe cutoff
near_dupes = []
kept_final = []
kept_hashes = []
for r in keep:
    is_dupe = any((r["phash"] - h) <= PHASH_THRESHOLD for h in kept_hashes)
    if is_dupe:
        near_dupes.append(r["path"])
    else:
        kept_hashes.append(r["phash"])
        kept_final.append(r)

print(f"{len(near_dupes)} near-duplicates (phash distance <= {PHASH_THRESHOLD})")
print(f"{len(kept_final)} images remain after dedup")
for c in CLASS_NAMES:
    n = sum(1 for r in kept_final if r["class"] == c)
    print(f"  {c}: {n}")
# Out:
# UNREADABLE, skipping: /content/crackdata/cracked/dataset.lnk cannot identify image file '/content/crackdata/cracked/dataset.lnk'
# scanned 1034 readable images
# 12 exact duplicates
# 72 near-duplicates (phash distance <= 6)
# 950 images remain after dedup
#   cracked: 367
#   not_cracked: 583

# %% [markdown]
# ## 5. Stratified 70/20/10 split
#
# Two-step `train_test_split` so the actual class ratio (~20% cracked) is
# preserved in every split rather than forced to 50/50 - production listings
# won't be balanced either, so val/test should look like what the model will
# actually see in the wild.

# %%
paths  = [r["path"] for r in kept_final]
labels = [r["class"] for r in kept_final]

train_p, rest_p, train_y, rest_y = train_test_split(
    paths, labels, test_size=(VAL_FRACTION + TEST_FRACTION),
    stratify=labels, random_state=SEED,
)
val_p, test_p, val_y, test_y = train_test_split(
    rest_p, rest_y,
    test_size=TEST_FRACTION / (VAL_FRACTION + TEST_FRACTION),
    stratify=rest_y, random_state=SEED,
)

def report(name, ys):
    from collections import Counter
    c = Counter(ys)
    print(f"{name:6s} total={len(ys):5d}  " + "  ".join(f"{k}={v}" for k, v in sorted(c.items())))

report("train", train_y)
report("val", val_y)
report("test", test_y)

# materialize as a directory tree so image_dataset_from_directory can use it
if os.path.exists(SPLIT_DIR):
    shutil.rmtree(SPLIT_DIR)
for split_name, sp, sy in [("train", train_p, train_y), ("valid", val_p, val_y), ("test", test_p, test_y)]:
    for c in CLASS_NAMES:
        os.makedirs(os.path.join(SPLIT_DIR, split_name, c), exist_ok=True)
    for p, y in zip(sp, sy):
        shutil.copy(p, os.path.join(SPLIT_DIR, split_name, y, os.path.basename(p)))

print("split materialized at", SPLIT_DIR)
# Out:
# train  total=  664  cracked=257  not_cracked=407
# val    total=  190  cracked=73  not_cracked=117
# test   total=   96  cracked=37  not_cracked=59
# split materialized at /content/crackeddataset_split

# %% [markdown]
# ## 6. Sanity check: zero overlap between splits
#
# This should print 0/0/0. If it doesn't, something in the split logic above is
# wrong - do not proceed to training until this is clean.

# %%
def hash_set(split):
    out = set()
    for c in CLASS_NAMES:
        d = os.path.join(SPLIT_DIR, split, c)
        for f in os.listdir(d):
            out.add(hashlib.md5(open(os.path.join(d, f), "rb").read()).hexdigest())
    return out

h_train, h_val, h_test = hash_set("train"), hash_set("valid"), hash_set("test")
print("train & val  overlap:", len(h_train & h_val))
print("train & test overlap:", len(h_train & h_test))
print("val   & test overlap:", len(h_val & h_test))
assert not (h_train & h_val) and not (h_train & h_test) and not (h_val & h_test), \
    "Split leakage detected - stop and investigate before training"
# Out:
# train & val  overlap: 0
# train & test overlap: 0
# val   & test overlap: 0

# %% [markdown]
# ## 7. Data pipeline (leak-fixed)
#
# Cached as **uint8** (442KB/image) instead of float32 (1.77MB/image), shuffle
# buffer sized in images-per-buffer terms that stay small even at 384px, and
# `prefetch(2)` instead of `AUTOTUNE` so the buffer can't grow unbounded on a
# memory-constrained runtime. This is the fix for the RAM-climbing-to-12.7GB
# problem from the v2 session.

# %%
def make_ds(split, shuffle):
    ds = tf.keras.utils.image_dataset_from_directory(
        os.path.join(SPLIT_DIR, split),
        image_size=IMG_SIZE,
        batch_size=None,
        label_mode="binary",
        shuffle=False,
        seed=SEED,
    )
    # cache uint8, not float32 - 4x smaller. round() before cast since resize
    # interpolation produces non-integer values and truncating biases dark.
    ds = ds.map(lambda x, y: (tf.cast(tf.round(x), tf.uint8), y), num_parallel_calls=4)
    ds = ds.cache(os.path.join(CACHE_DIR, f"{split}.cache"))
    if shuffle:
        ds = ds.shuffle(256, seed=SEED, reshuffle_each_iteration=True)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.map(lambda x, y: (tf.cast(x, tf.float32), y), num_parallel_calls=2)
    return ds.prefetch(2)

# wipe any stale cache from a previous run/config before rebuilding
for f in os.listdir(CACHE_DIR):
    os.remove(os.path.join(CACHE_DIR, f))

class_names = sorted(os.listdir(os.path.join(SPLIT_DIR, "train")))
print("label 0 =", class_names[0], "| label 1 =", class_names[1])

train_ds = make_ds("train", shuffle=True)
val_ds   = make_ds("valid", shuffle=False)
test_ds  = make_ds("test",  shuffle=False)

xb, yb = next(iter(train_ds))
print("batch:", xb.shape, xb.dtype, "range:", float(tf.reduce_min(xb)), "-", float(tf.reduce_max(xb)))
# Out:
# label 0 = cracked | label 1 = not_cracked
# Found 664 files belonging to 2 classes.
# Found 190 files belonging to 2 classes.
# Found 96 files belonging to 2 classes.
# batch: (16, 384, 384, 3) <dtype: 'float32'> range: 0.0 - 255.0

# %% [markdown]
# ## 8. Class weights (computed on the new train split)

# %%
from collections import Counter
train_counts = Counter(train_y)
n_total = sum(train_counts.values())
class_weight = {i: n_total / (2.0 * train_counts[c]) for i, c in enumerate(class_names)}
print("class_weight:", {k: round(v, 3) for k, v in class_weight.items()})
# Out:
# class_weight: {0: 1.292, 1: 0.816}

# %% [markdown]
# ## 9. Augmentation
#
# Unchanged from v2 - upright, hand-held listing photos, so no vertical flips or
# large rotations. Brightness/contrast jitter stays aggressive for OLX-typical
# glare and bad indoor lighting.

# %%
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomTranslation(0.08, 0.08),
    layers.RandomZoom(0.15),
    layers.RandomBrightness(0.25, value_range=(0, 255)),
    layers.RandomContrast(0.25),
], name="augment")

# %% [markdown]
# ## 10. Model - ConvNeXt-**Tiny**
#
# Switched from Base (~88M params) to Tiny (~28M params). At ~1150 train images
# with only ~235 cracked, Base has enough capacity to fit shortcuts instead of
# the actual crack pattern - which is consistent with what the v2 Grad-CAM
# showed (diffuse activation everywhere, not localized to cracks). Cracks are a
# local texture/edge pattern; Tiny's shallower depth is not a real handicap here.
#
# Head unchanged: avg+max pooling concat so a hairline crack occupying a small
# fraction of the frame isn't diluted by average pooling alone.

# %%
def build_model():
    base = tf.keras.applications.ConvNeXtTiny(
        include_top=False,
        weights="imagenet",
        input_shape=(*IMG_SIZE, 3),
    )
    base.trainable = False

    feat_in = layers.Input(shape=base.output_shape[1:], name="features")
    avg = layers.GlobalAveragePooling2D()(feat_in)
    mx  = layers.GlobalMaxPooling2D()(feat_in)
    h   = layers.Concatenate()([avg, mx])
    h   = layers.BatchNormalization()(h)
    h   = layers.Dropout(0.3)(h)
    h   = layers.Dense(256, activation="relu")(h)
    h   = layers.Dropout(0.4)(h)
    out = layers.Dense(1, activation="sigmoid", dtype="float32")(h)
    head = models.Model(feat_in, out, name="head")

    inputs  = layers.Input(shape=(*IMG_SIZE, 3), name="image")
    x       = data_augmentation(inputs)
    feats   = base(x)
    outputs = head(feats)
    return models.Model(inputs, outputs, name="crack_detector"), base, head


def make_metrics():
    return [
        tf.keras.metrics.BinaryAccuracy(name="acc"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="pr_auc", curve="PR"),
        tf.keras.metrics.AUC(name="roc_auc"),
    ]


model, base_model, head_model = build_model()
model.summary()
print("trainable params:", sum(np.prod(v.shape) for v in model.trainable_variables))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_tiny_notop.h5
# 111650432/111650432 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "crack_detector"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 384, 384, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augment (Sequential)            │ (None, 384, 384, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ convnext_tiny (Functional)      │ (None, 12, 12, 768)    │    27,820,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ head (Functional)               │ (None, 1)              │       399,873 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,220,001 (107.65 MB)
#  Trainable params: 396,801 (1.51 MB)
#  Non-trainable params: 27,823,200 (106.14 MB)
# trainable params: 396801

# %% [markdown]
# ## 11. Stage 1 - train the head on a frozen backbone

# %%
def make_callbacks(patience_es, patience_lr):
    return [
        callbacks.ModelCheckpoint(CKPT, monitor="val_pr_auc", mode="max",
                                  save_best_only=True, verbose=1),
        callbacks.EarlyStopping(monitor="val_pr_auc", mode="max",
                                patience=patience_es, restore_best_weights=True,
                                verbose=1),
        callbacks.ReduceLROnPlateau(monitor="val_pr_auc", mode="max", factor=0.5,
                                    patience=patience_lr, min_lr=1e-7, verbose=1),
    ]

model.compile(
    optimizer=optimizers.Adam(LR_HEAD),
    loss="binary_crossentropy",
    metrics=make_metrics(),
)

print("--- Stage 1: frozen backbone, head only ---")
hist_head = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_HEAD,
    class_weight=class_weight,
    callbacks=make_callbacks(patience_es=4, patience_lr=2),
)
# Out:
# --- Stage 1: frozen backbone, head only ---
# Epoch 1/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.6729 - loss: 0.7955 - pr_auc: 0.6406 - precision: 0.5864 - recall: 0.4429 - roc_auc: 0.7034
# Epoch 1: val_pr_auc improved from None to 0.96235, saving model to /content/best_crack_model.keras
#
# Epoch 1: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - acc: 0.7093 - loss: 0.7242 - pr_auc: 0.8845 - precision: 0.8567 - recall: 0.6314 - roc_auc: 0.8252 - val_acc: 0.8632 - val_loss: 0.3325 - val_pr_auc: 0.9624 - val_precision: 0.8227 - val_recall: 0.9915 - val_roc_auc: 0.9498 - learning_rate: 0.0010
# Epoch 2/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - acc: 0.6929 - loss: 1.4963 - pr_auc: 0.6437 - precision: 0.5959 - recall: 0.8297 - roc_auc: 0.8172
# Epoch 2: val_pr_auc did not improve from 0.96235
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 225ms/step - acc: 0.7364 - loss: 0.8424 - pr_auc: 0.8158 - precision: 0.8169 - recall: 0.7346 - roc_auc: 0.8059 - val_acc: 0.8789 - val_loss: 0.3127 - val_pr_auc: 0.9547 - val_precision: 0.9052 - val_recall: 0.8974 - val_roc_auc: 0.9411 - learning_rate: 0.0010
# Epoch 3/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - acc: 0.6957 - loss: 1.1877 - pr_auc: 0.6828 - precision: 0.5934 - recall: 0.8073 - roc_auc: 0.8061
# Epoch 3: val_pr_auc did not improve from 0.96235
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - acc: 0.7726 - loss: 0.6594 - pr_auc: 0.8580 - precision: 0.8299 - recall: 0.7912 - roc_auc: 0.8431 - val_acc: 0.8421 - val_loss: 0.3943 - val_pr_auc: 0.9482 - val_precision: 0.7959 - val_recall: 1.0000 - val_roc_auc: 0.9321 - learning_rate: 0.0010
# Epoch 4/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - acc: 0.6973 - loss: 1.1860 - pr_auc: 0.6969 - precision: 0.5755 - recall: 0.8690 - roc_auc: 0.8370
# Epoch 4: val_pr_auc improved from 0.96235 to 0.96898, saving model to /content/best_crack_model.keras
#
# Epoch 4: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 254ms/step - acc: 0.7892 - loss: 0.6112 - pr_auc: 0.8619 - precision: 0.8248 - recall: 0.8329 - roc_auc: 0.8459 - val_acc: 0.8947 - val_loss: 0.2471 - val_pr_auc: 0.9690 - val_precision: 0.8943 - val_recall: 0.9402 - val_roc_auc: 0.9559 - learning_rate: 5.0000e-04
# Epoch 5/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - acc: 0.7480 - loss: 0.7009 - pr_auc: 0.8154 - precision: 0.6294 - recall: 0.8714 - roc_auc: 0.8813
# Epoch 5: val_pr_auc did not improve from 0.96898
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - acc: 0.8042 - loss: 0.4418 - pr_auc: 0.9171 - precision: 0.8454 - recall: 0.8329 - roc_auc: 0.8951 - val_acc: 0.9053 - val_loss: 0.2460 - val_pr_auc: 0.9646 - val_precision: 0.8779 - val_recall: 0.9829 - val_roc_auc: 0.9537 - learning_rate: 5.0000e-04
# Epoch 6/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - acc: 0.7786 - loss: 0.5993 - pr_auc: 0.8563 - precision: 0.6485 - recall: 0.8754 - roc_auc: 0.9104
# Epoch 6: val_pr_auc improved from 0.96898 to 0.97734, saving model to /content/best_crack_model.keras
#
# Epoch 6: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 255ms/step - acc: 0.8283 - loss: 0.3934 - pr_auc: 0.9319 - precision: 0.8747 - recall: 0.8403 - roc_auc: 0.9140 - val_acc: 0.9053 - val_loss: 0.2185 - val_pr_auc: 0.9773 - val_precision: 0.8898 - val_recall: 0.9658 - val_roc_auc: 0.9662 - learning_rate: 5.0000e-04
# Epoch 7/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - acc: 0.7833 - loss: 0.6747 - pr_auc: 0.8190 - precision: 0.6545 - recall: 0.8997 - roc_auc: 0.9000
# Epoch 7: val_pr_auc did not improve from 0.97734
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - acc: 0.8328 - loss: 0.4259 - pr_auc: 0.9232 - precision: 0.8682 - recall: 0.8575 - roc_auc: 0.9073 - val_acc: 0.9105 - val_loss: 0.2263 - val_pr_auc: 0.9718 - val_precision: 0.8846 - val_recall: 0.9829 - val_roc_auc: 0.9621 - learning_rate: 5.0000e-04
# Epoch 8/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - acc: 0.8019 - loss: 0.5998 - pr_auc: 0.9049 - precision: 0.6916 - recall: 0.8930 - roc_auc: 0.9176
# Epoch 8: val_pr_auc improved from 0.97734 to 0.97822, saving model to /content/best_crack_model.keras
#
# Epoch 8: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - acc: 0.8419 - loss: 0.3819 - pr_auc: 0.9384 - precision: 0.8892 - recall: 0.8477 - roc_auc: 0.9192 - val_acc: 0.9316 - val_loss: 0.1948 - val_pr_auc: 0.9782 - val_precision: 0.9262 - val_recall: 0.9658 - val_roc_auc: 0.9691 - learning_rate: 5.0000e-04
# Epoch 9/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - acc: 0.8198 - loss: 0.5085 - pr_auc: 0.8949 - precision: 0.7179 - recall: 0.9232 - roc_auc: 0.9424
# Epoch 9: val_pr_auc did not improve from 0.97822
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 235ms/step - acc: 0.8554 - loss: 0.3405 - pr_auc: 0.9519 - precision: 0.8957 - recall: 0.8649 - roc_auc: 0.9336 - val_acc: 0.9368 - val_loss: 0.1898 - val_pr_auc: 0.9756 - val_precision: 0.9268 - val_recall: 0.9744 - val_roc_auc: 0.9669 - learning_rate: 5.0000e-04
# Epoch 10/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - acc: 0.8065 - loss: 0.5999 - pr_auc: 0.8320 - precision: 0.6862 - recall: 0.8790 - roc_auc: 0.8948
# Epoch 10: val_pr_auc did not improve from 0.97822
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - acc: 0.8780 - loss: 0.3175 - pr_auc: 0.9463 - precision: 0.9035 - recall: 0.8968 - roc_auc: 0.9390 - val_acc: 0.9368 - val_loss: 0.1986 - val_pr_auc: 0.9716 - val_precision: 0.9268 - val_recall: 0.9744 - val_roc_auc: 0.9642 - learning_rate: 5.0000e-04
# Epoch 11/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - acc: 0.8322 - loss: 0.4883 - pr_auc: 0.8808 - precision: 0.6995 - recall: 0.8817 - roc_auc: 0.9072
# Epoch 11: val_pr_auc did not improve from 0.97822
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - acc: 0.8614 - loss: 0.3228 - pr_auc: 0.9517 - precision: 0.9028 - recall: 0.8673 - roc_auc: 0.9381 - val_acc: 0.9316 - val_loss: 0.2157 - val_pr_auc: 0.9601 - val_precision: 0.9262 - val_recall: 0.9658 - val_roc_auc: 0.9582 - learning_rate: 2.5000e-04
# Epoch 12/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - acc: 0.8414 - loss: 0.4297 - pr_auc: 0.9173 - precision: 0.6974 - recall: 0.9291 - roc_auc: 0.9554
# Epoch 12: val_pr_auc did not improve from 0.97822
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - acc: 0.8645 - loss: 0.3216 - pr_auc: 0.9526 - precision: 0.8992 - recall: 0.8771 - roc_auc: 0.9374 - val_acc: 0.9316 - val_loss: 0.2000 - val_pr_auc: 0.9759 - val_precision: 0.9262 - val_recall: 0.9658 - val_roc_auc: 0.9675 - learning_rate: 2.5000e-04
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %% [markdown]
# ## 12. Stage 2 - fine-tune the top of the backbone
#
# Only the top 15% unfrozen (down from 25% in v2) given the smaller dataset.
# Recompile is required after flipping `trainable` - Keras traces the training
# function at compile time, so skipping this silently leaves the backbone frozen
# regardless of the flag.
#
# If you want a larger batch size for stage 2, change `BATCH_SIZE` and rerun
# cell 7 to rebuild the datasets before this cell - GPU RAM headroom (check the
# Colab resource gauge) tells you how far you can push it.

# %%
base_model.trainable = True
cut = int(len(base_model.layers) * (1 - FINE_TUNE_FRACTION))
for layer in base_model.layers[:cut]:
    layer.trainable = False

n_trainable = sum(bool(l.trainable) for l in base_model.layers)
print(f"unfroze {n_trainable}/{len(base_model.layers)} backbone layers (from index {cut})")

model.compile(
    optimizer=optimizers.Adam(LR_FINETUNE),
    loss="binary_crossentropy",
    metrics=make_metrics(),
)

initial = hist_head.epoch[-1] + 1
print("--- Stage 2: fine-tuning ---")
hist_ft = model.fit(
    train_ds,
    validation_data=val_ds,
    initial_epoch=initial,
    epochs=initial + EPOCHS_FINETUNE,
    class_weight=class_weight,
    callbacks=make_callbacks(patience_es=6, patience_lr=3),
)
# Out:
# unfroze 20/133 backbone layers (from index 113)
# --- Stage 2: fine-tuning ---
# Epoch 13/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - acc: 0.8195 - loss: 0.5678 - pr_auc: 0.9012 - precision: 0.6733 - recall: 0.9480 - roc_auc: 0.9465
# Epoch 13: val_pr_auc improved from None to 0.97981, saving model to /content/best_crack_model.keras
#
# Epoch 13: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - acc: 0.8614 - loss: 0.3572 - pr_auc: 0.9453 - precision: 0.8851 - recall: 0.8894 - roc_auc: 0.9279 - val_acc: 0.9368 - val_loss: 0.1883 - val_pr_auc: 0.9798 - val_precision: 0.9339 - val_recall: 0.9658 - val_roc_auc: 0.9709 - learning_rate: 1.0000e-05
# Epoch 14/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - acc: 0.7999 - loss: 0.5777 - pr_auc: 0.8671 - precision: 0.6711 - recall: 0.9212 - roc_auc: 0.9218
# Epoch 14: val_pr_auc improved from 0.97981 to 0.98100, saving model to /content/best_crack_model.keras
#
# Epoch 14: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 372ms/step - acc: 0.8554 - loss: 0.3503 - pr_auc: 0.9446 - precision: 0.8747 - recall: 0.8919 - roc_auc: 0.9302 - val_acc: 0.9368 - val_loss: 0.1829 - val_pr_auc: 0.9810 - val_precision: 0.9339 - val_recall: 0.9658 - val_roc_auc: 0.9723 - learning_rate: 1.0000e-05
# Epoch 15/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - acc: 0.8531 - loss: 0.4441 - pr_auc: 0.9284 - precision: 0.7253 - recall: 0.9601 - roc_auc: 0.9610
# Epoch 15: val_pr_auc improved from 0.98100 to 0.98136, saving model to /content/best_crack_model.keras
#
# Epoch 15: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 377ms/step - acc: 0.8870 - loss: 0.3046 - pr_auc: 0.9546 - precision: 0.9029 - recall: 0.9140 - roc_auc: 0.9466 - val_acc: 0.9368 - val_loss: 0.1813 - val_pr_auc: 0.9814 - val_precision: 0.9339 - val_recall: 0.9658 - val_roc_auc: 0.9727 - learning_rate: 1.0000e-05
# Epoch 16/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - acc: 0.7858 - loss: 0.6125 - pr_auc: 0.8367 - precision: 0.6400 - recall: 0.8935 - roc_auc: 0.8959
# Epoch 16: val_pr_auc improved from 0.98136 to 0.98244, saving model to /content/best_crack_model.keras
#
# Epoch 16: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 455ms/step - acc: 0.8630 - loss: 0.3536 - pr_auc: 0.9487 - precision: 0.8854 - recall: 0.8919 - roc_auc: 0.9332 - val_acc: 0.9368 - val_loss: 0.1791 - val_pr_auc: 0.9824 - val_precision: 0.9339 - val_recall: 0.9658 - val_roc_auc: 0.9741 - learning_rate: 1.0000e-05
# Epoch 17/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - acc: 0.8224 - loss: 0.5038 - pr_auc: 0.9237 - precision: 0.6654 - recall: 0.9365 - roc_auc: 0.9384
# Epoch 17: val_pr_auc improved from 0.98244 to 0.98355, saving model to /content/best_crack_model.keras
#
# Epoch 17: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 436ms/step - acc: 0.8735 - loss: 0.3219 - pr_auc: 0.9585 - precision: 0.8854 - recall: 0.9115 - roc_auc: 0.9397 - val_acc: 0.9368 - val_loss: 0.1761 - val_pr_auc: 0.9835 - val_precision: 0.9339 - val_recall: 0.9658 - val_roc_auc: 0.9754 - learning_rate: 1.0000e-05
# Epoch 18/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - acc: 0.8215 - loss: 0.5585 - pr_auc: 0.8342 - precision: 0.6808 - recall: 0.8974 - roc_auc: 0.8975
# Epoch 18: val_pr_auc improved from 0.98355 to 0.98419, saving model to /content/best_crack_model.keras
#
# Epoch 18: finished saving model to /content/best_crack_model.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 442ms/step - acc: 0.8765 - loss: 0.3323 - pr_auc: 0.9455 - precision: 0.8916 - recall: 0.9091 - roc_auc: 0.9365 - val_acc: 0.9421 - val_loss: 0.1740 - val_pr_auc: 0.9842 - val_precision: 0.9344 - val_recall: 0.9744 - val_roc_auc: 0.9763 - learning_rate: 1.0000e-05
# Epoch 19/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - acc: 0.8818 - loss: 0.3862 - pr_auc: 0.9285 - precision: 0.7827 - recall: 0.9360 - roc_auc: 0.9432
# Epoch 19: val_pr_auc did not improve from 0.98419
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 331ms/step - acc: 0.9066 - loss: 0.2799 - pr_auc: 0.9618 - precision: 0.9177 - recall: 0.9312 - roc_auc: 0.9522 - val_acc: 0.9421 - val_loss: 0.1725 - val_pr_auc: 0.9836 - val_precision: 0.9344 - val_recall: 0.9744 - val_roc_auc: 0.9756 - learning_rate: 1.0000e-05
# Epoch 20/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - acc: 0.8254 - loss: 0.5005 - pr_auc: 0.9032 - precision: 0.6899 - recall: 0.9159 - roc_auc: 0.9252
# Epoch 20: val_pr_auc did not improve from 0.98419
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 335ms/step - acc: 0.8765 - loss: 0.3008 - pr_auc: 0.9577 - precision: 0.8935 - recall: 0.9066 - roc_auc: 0.9446 - val_acc: 0.9421 - val_loss: 0.1713 - val_pr_auc: 0.9839 - val_precision: 0.9344 - val_recall: 0.9744 - val_roc_auc: 0.9762 - learning_rate: 1.0000e-05
# Epoch 21/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - acc: 0.8567 - loss: 0.3191 - pr_auc: 0.9441 - precision: 0.7265 - recall: 0.9237 - roc_auc: 0.9514
# Epoch 21: val_pr_auc did not improve from 0.98419
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 336ms/step - acc: 0.8825 - loss: 0.2484 - pr_auc: 0.9759 - precision: 0.9102 - recall: 0.8968 - roc_auc: 0.9620 - val_acc: 0.9421 - val_loss: 0.1715 - val_pr_auc: 0.9839 - val_precision: 0.9344 - val_recall: 0.9744 - val_roc_auc: 0.9762 - learning_rate: 1.0000e-05
# Epoch 22/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - acc: 0.7920 - loss: 0.5008 - pr_auc: 0.9362 - precision: 0.6514 - recall: 0.9136 - roc_auc: 0.9388
# Epoch 22: val_pr_auc did not improve from 0.98419
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 337ms/step - acc: 0.8524 - loss: 0.3015 - pr_auc: 0.9643 - precision: 0.8796 - recall: 0.8796 - roc_auc: 0.9463 - val_acc: 0.9421 - val_loss: 0.1715 - val_pr_auc: 0.9841 - val_precision: 0.9344 - val_recall: 0.9744 - val_roc_auc: 0.9765 - learning_rate: 5.0000e-06
# Epoch 23/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - acc: 0.8795 - loss: 0.3522 - pr_auc: 0.9337 - precision: 0.7776 - recall: 0.9308 - roc_auc: 0.9435
# Epoch 23: val_pr_auc did not improve from 0.98419
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 338ms/step - acc: 0.8886 - loss: 0.2743 - pr_auc: 0.9677 - precision: 0.9152 - recall: 0.9017 - roc_auc: 0.9534 - val_acc: 0.9421 - val_loss: 0.1714 - val_pr_auc: 0.9838 - val_precision: 0.9344 - val_recall: 0.9744 - val_roc_auc: 0.9761 - learning_rate: 5.0000e-06
# Epoch 24/27
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - acc: 0.8366 - loss: 0.5164 - pr_auc: 0.8862 - precision: 0.6898 - recall: 0.9323 - roc_auc: 0.9410
# Epoch 24: val_pr_auc did not improve from 0.98419
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 340ms/step - acc: 0.8901 - loss: 0.2933 - pr_auc: 0.9622 - precision: 0.9113 - recall: 0.9091 - roc_auc: 0.9516 - val_acc: 0.9421 - val_loss: 0.1721 - val_pr_auc: 0.9839 - val_precision: 0.9344 - val_recall: 0.9744 - val_roc_auc: 0.9762 - learning_rate: 5.0000e-06
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %% [markdown]
# ## 13. Training curves

# %%
def merge_hist(*hs):
    out = {}
    for h in hs:
        for k, v in h.history.items():
            out.setdefault(k, []).extend(v)
    return out

H      = merge_hist(hist_head, hist_ft)
switch = len(hist_head.history["loss"])

panels = [("loss", "val_loss", "Loss"),
          ("pr_auc", "val_pr_auc", "PR-AUC"),
          ("recall", "val_recall", "Recall"),
          ("precision", "val_precision", "Precision")]

fig, axes = plt.subplots(1, 4, figsize=(20, 4))
for ax, (a, b, title) in zip(axes, panels):
    ax.plot(H[a], label="train")
    ax.plot(H[b], label="val")
    ax.axvline(switch - 0.5, ls="--", c="gray", lw=1)
    ax.set_title(f"{title}  (dashed = fine-tune starts)")
    ax.set_xlabel("epoch")
    ax.legend()
plt.tight_layout()
plt.show()

print("If val metrics separate from train this cleanly and this early again,")
print("re-run the overlap check in cell 6 before trusting the result.")
# Out:
# If val metrics separate from train this cleanly and this early again,
# re-run the overlap check in cell 6 before trusting the result.

# %% [markdown]
# ## 14. Pick the decision threshold on validation

# %%
def predict_probs(ds):
    y_true = np.concatenate([y for _, y in ds]).ravel()
    y_prob = model.predict(ds, verbose=0).ravel()
    return y_true, y_prob

val_y_arr, val_p = predict_probs(val_ds)
prec, rec, thr = precision_recall_curve(val_y_arr, val_p)

ok = np.where(prec[:-1] >= TARGET_PRECISION)[0]
if len(ok):
    best = ok[np.argmax(rec[:-1][ok])]
    THRESHOLD = float(thr[best])
    print(f"threshold = {THRESHOLD:.3f}  ->  val precision {prec[best]:.3f}, recall {rec[best]:.3f}")
else:
    THRESHOLD = 0.5
    print(f"no threshold reaches precision {TARGET_PRECISION}; falling back to 0.5")

print("val PR-AUC :", round(average_precision_score(val_y_arr, val_p), 4))
print("val ROC-AUC:", round(roc_auc_score(val_y_arr, val_p), 4))

plt.figure(figsize=(5, 4))
plt.plot(rec, prec)
plt.axhline(TARGET_PRECISION, ls="--", c="gray", lw=1)
plt.xlabel("Recall"); plt.ylabel("Precision")
plt.title("Validation precision-recall")
plt.show()
# Out:
# threshold = 0.108  ->  val precision 0.900, recall 1.000
# val PR-AUC : 0.9839
# val ROC-AUC: 0.9759

# %% [markdown]
# ## 15. Test evaluation

# %%
test_y_arr, test_p = predict_probs(test_ds)
test_pred = (test_p >= 0.5).astype(int)

print("test PR-AUC :", round(average_precision_score(test_y_arr, test_p), 4))
print("test ROC-AUC:", round(roc_auc_score(test_y_arr, test_p), 4))
print("n test images:", len(test_y_arr), "(", int(test_y_arr.sum()), "cracked )")
print()
print(classification_report(test_y_arr, test_pred, target_names=class_names, digits=3))

cm = confusion_matrix(test_y_arr, test_pred)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Reds",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted"); plt.ylabel("Actual")
plt.title(f"Confusion matrix @ threshold {THRESHOLD:.3f}")
plt.show()
# Out:
# test PR-AUC : 0.9931
# test ROC-AUC: 0.9885
# n test images: 96 ( 59 cracked )
#
#               precision    recall  f1-score   support
#
#      cracked      1.000     0.811     0.896        37
#  not_cracked      0.894     1.000     0.944        59
#
#     accuracy                          0.927        96
#    macro avg      0.947     0.905     0.920        96
# weighted avg      0.935     0.927     0.925        96

# %% [markdown]
# ## 16. Grad-CAM sanity check - run this before trusting any metric above
#
# Last run, this was the cell that revealed the model wasn't looking at cracks
# at all (diffuse activation across the whole frame regardless of content).
# Check this **first** if numbers look too good - a tight heatmap on the actual
# fracture line is the real evidence of a working model, not PR-AUC alone.

# %%
def grad_cam(img):
    x = tf.expand_dims(img, 0)
    with tf.GradientTape() as tape:
        feats = base_model(x, training=False)
        tape.watch(feats)
        score = head_model(feats, training=False)[:, 0]
    grads   = tape.gradient(score, feats)
    weights = tf.reduce_mean(tf.cast(grads, tf.float32), axis=(1, 2))
    feats   = tf.cast(feats, tf.float32)
    cam     = tf.reduce_sum(feats * weights[:, None, None, :], axis=-1)[0]
    cam     = tf.nn.relu(cam)
    cam     = cam / (tf.reduce_max(cam) + 1e-8)
    return tf.image.resize(cam[..., None], IMG_SIZE).numpy().squeeze()

# Sample specifically from the *cracked* test images this time, not just
# highest-confidence predictions - we need to see how it handles known cracks.
cracked_dir = os.path.join(SPLIT_DIR, "test", "cracked")
sample_files = sorted(os.listdir(cracked_dir))[:6]

images, probs = [], []
for f in sample_files:
    img = tf.keras.utils.load_img(os.path.join(cracked_dir, f), target_size=IMG_SIZE)
    arr = tf.keras.utils.img_to_array(img)
    images.append(arr)
    probs.append(float(model.predict(arr[None, ...], verbose=0)[0, 0]))

fig, axes = plt.subplots(2, len(images), figsize=(20, 7))
for j, (img, p) in enumerate(zip(images, probs)):
    axes[0, j].imshow(img.astype("uint8"))
    axes[0, j].set_title(f"p={p:.2f} (true: cracked)")
    axes[0, j].axis("off")
    axes[1, j].imshow(img.astype("uint8"))
    axes[1, j].imshow(grad_cam(img), cmap="jet", alpha=0.45)
    axes[1, j].axis("off")
plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function conv.<locals>._conv_xla at 0x7967e1279f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function conv.<locals>._conv_xla at 0x7967e127b380> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %% [markdown]
# ## 17. Save

# %%
OUT_MODEL = "/content/crack_detector_convnext_tiny.keras"
OUT_META  = "/content/crack_detector_meta.json"

model.save(OUT_MODEL)

meta = {
    "backbone": "ConvNeXtTiny",
    "img_size": list(IMG_SIZE),
    "input_range": "float32 [0,255] - ConvNeXt normalizes internally, do NOT rescale",
    "class_names": class_names,
    "positive_class": class_names[1],
    "threshold": THRESHOLD,
    "target_precision": TARGET_PRECISION,
    "test_pr_auc": float(average_precision_score(test_y_arr, test_p)),
    "test_roc_auc": float(roc_auc_score(test_y_arr, test_p)),
    "test_n": int(len(test_y_arr)),
    "fine_tune_fraction": FINE_TUNE_FRACTION,
    "split": {"val_fraction": VAL_FRACTION, "test_fraction": TEST_FRACTION},
}
with open(OUT_META, "w") as f:
    json.dump(meta, f, indent=2)

for p in (OUT_MODEL, OUT_META):
    shutil.copy(p, os.path.join(DRIVE_POOL, os.path.basename(p)))

print(json.dumps(meta, indent=2))
# Out:
# {
#   "backbone": "ConvNeXtTiny",
#   "img_size": [
#     384,
#     384
#   ],
#   "input_range": "float32 [0,255] - ConvNeXt normalizes internally, do NOT rescale",
#   "class_names": [
#     "cracked",
#     "not_cracked"
#   ],
#   "positive_class": "not_cracked",
#   "threshold": 0.10848277062177658,
#   "target_precision": 0.9,
#   "test_pr_auc": 0.9930675838149022,
#   "test_roc_auc": 0.9885478699038021,
#   "test_n": 96,
#   "fine_tune_fraction": 0.15,
#   "split": {
#     "val_fraction": 0.2,
#     "test_fraction": 0.1
#   }
# }
